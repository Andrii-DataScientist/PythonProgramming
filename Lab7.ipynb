# %% [markdown]
# Source: DataCamp.com, RealPython.com

# %% [markdown]
# ## Answering Data Science Questions

# %% [markdown]
# Chicago Open Data Portal https://data.cityofchicago.org/

# %% [markdown]
# Let's get started! The exercises in this chapter are intentionally more challenging, to give you a chance to really solidify your knowledge. Don't lose heart if you find yourself stuck; think back to the concepts you've learned in previous chapters and how you can apply them to this crime dataset. Good luck!
#
# Your data file, `crime_sampler.csv` contains the date (1st column), block where it occurred (2nd column), primary type of the crime (3rd), description of the crime (4th), description of the location (5th), if an arrest was made (6th), was it a domestic case (7th), and city district (8th).
#
# Here, however, you'll focus only 4 columns: The date, type of crime, location, and whether or not the crime resulted in an arrest.
#
# Your job in this exercise is to use a CSV Reader to load up a list to hold the data you're going to analyze.
#
# **Instructions**
# - Import the Python `csv` module.
# - Create a Python file object in read mode for `crime_sampler.csv` called `csvfile`.
# - Create an empty list called `crime_data`.
# - Loop over a csv reader on the file object :
#   - Inside the loop, append the date (first element), type of crime (third element), location description (fifth element), and arrest (sixth element) to the `crime_data` list.
# - Remove the first element (headers) from the `crime_data` list.
# - Print the first 10 records of the crime_data list. This has been done for you!

# %%
# Import the csv module
import csv

# Create the file object: csvfile
csvfile = open('CSV/crime_sampler.csv','r')

# Create an empty list: crime_data
crime_data = []

# Loop over a csv reader on the file object
for row in csv.reader(csvfile):
    #print(row)
    # Append the date, type of crime, location description, and arrest
    crime_data.append((row[0], row[2], row[4], row[5]))
    #print(crime_data[:5])
    #print(row[0])
# Remove the first element from crime_data
del crime_data[0]

# Print the first 10 records
print(crime_data[:10])

# %%
#result: [('05/23/2016 05:35:00 PM', 'ASSAULT', 'STREET', 'false'), ('03/26/2016 08:20:00 PM', 'BURGLARY', 'SMALL RETAIL STORE', 'false'), ('04/25/2016 03:05:00 PM', 'THEFT', 'DEPARTMENT STORE', 'true'), ('04/26/2016 05:30:00 PM', 'BATTERY', 'SIDEWALK', 'false'), ('06/19/2016 01:15:00 AM', 'BATTERY', 'SIDEWALK', 'false'), ('05/28/2016 08:00:00 PM', 'BATTERY', 'GAS STATION', 'false'), ('07/03/2016 03:43:00 PM', 'THEFT', 'OTHER', 'false'), ('06/11/2016 06:55:00 PM', 'PUBLIC PEACE VIOLATION', 'STREET', 'true'), ('10/04/2016 10:20:00 AM', 'BATTERY', 'STREET', 'true'), ('02/14/2017 09:00:00 PM', 'CRIMINAL DAMAGE', 'PARK PROPERTY', 'false')]

# %% [markdown]
# Using the `crime_data` list from the prior exercise, you'll answer a common question that arises when dealing with crime data: How many crimes are committed each month?
#
# Feel free to use the IPython Shell to explore the `crime_data` list - it has been pre-loaded for you. For example, `crime_data[0][0]` will show you the first column of the first row which, in this case, is the date and time time that the crime occurred.
#
# **Instructions**
#
# - Import `Counter` from `collections` and `datetime` from `datetime`.
# - Create a Counter object called `crimes_by_month`.
# - Loop over the `crime_data` list:
#   - Using the `datetime.strptime()` function, convert the first element of each item into a Python Datetime Object called `date`.
#   - Increment the counter for the month associated with this row by one. You can access the month of `date` using `date.month`.
# - Print the 3 most common months for crime.

# %%
# Import necessary modules
from collections import Counter
from datetime import datetime
# Create a Counter Object: crimes_by_month
crimes_by_month = Counter()

# Loop over the crime_data list
for date in crime_data :
    #print(date[:5])
    # Convert the first element of each item into a Python Datetime Object: date
    date = datetime.strptime(date[:][0], '%m/%d/%Y %I:%M:%S %p')
    #print(date)
    # Increment the counter for the month of the row by one
    crimes_by_month[date.month] += 1
    
# Print the 3 most common months for crime
print(crimes_by_month.most_common(3))
# Out:
# [(1, 1948), (2, 1862), (7, 1257)]

# %%
#result: [(1, 1948), (2, 1862), (7, 1257)]

# %% [markdown]
# Now let's flip your `crime_data` list into a dictionary keyed by month with a list of location values for each month, and filter down to the records for the year 2016. Remember you can use the shell to look at the `crime_data` list, such as `crime_data[1][4]` to see the location of the crime in the second item of the list (since lists start at 0).
#
# **Instructions**
# - Import `defaultdict` from `collections` and `datetime` from `datetime`.
# - Create a dictionary that defaults to a `list` called `locations_by_month`.
# - Loop over the `crime_data` list:
#   - Convert the first element to a date object exactly like you did in the previous exercise.
#   - If the year is `2016`, set the key of `locations_by_month` to be the `month` of `date` and append the location (fifth element of `row`) to the values list.
# - Print the dictionary. This has been done for you!

# %%
# Import the pandas package
import pandas as pd

# Import data as DataFrame: df
df = pd.read_csv('CSV/crime_sampler.csv')

# Create list of lists (rows)
crime_data = df.values.tolist()

# %%
# Import necessary modules
from collections import defaultdict
from datetime import datetime

# Create a dictionary that defaults to a list: locations_by_month
locations_by_month = defaultdict(list)

# Loop over the crime_data list
for row in crime_data:
    # Convert the first element to a date object
    date = datetime.strptime(row[0], '%m/%d/%Y %I:%M:%S %p')
    #print(date.month)
    # If the year is 2016 
    if date.year == 2016:
        # Set the dictionary key to the month and add the location (fifth element) to the values list
        locations_by_month[date.month].append(row[4])
    
# Print the dictionary
print(locations_by_month)
# Out:
# defaultdict(<class 'list'>, {5: ['STREET', 'GAS STATION', nan, 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'STREET', 'RESTAURANT', 'SMALL RETAIL STORE', 'STREET', 'APARTMENT', 'SIDEWALK', 'PARKING LOT/GARAGE(NON.RESID.)', 'DEPARTMENT STORE', 'PARKING LOT/GARAGE(NON.RESID.)', 'SMALL RETAIL STORE', 'RESIDENCE', 'STREET', 'RESIDENCE', 'APARTMENT', 'RESIDENCE-GARAGE', 'APARTMENT', 'ALLEY', 'HIGHWAY/EXPRESSWAY', 'SIDEWALK', 'POLICE FACILITY/VEH PARKING LOT', 'RESIDENCE', 'STREET', 'APARTMENT', 'RESIDENCE PORCH/HALLWAY', 'STREET', 'RESIDENCE', 'SMALL RETAIL STORE', 'SCHOOL, PUBLIC, BUILDING', 'SIDEWALK', 'SCHOOL, PUBLIC, BUILDING', 'STREET', 'APARTMENT', 'STREET', 'SIDEWALK', 'SMALL RETAIL STORE', 'ALLEY', 'OTHER', 'APARTMENT', 'STREET', 'RESIDENCE', 'GROCERY FOOD STORE', 'SIDEWALK', 'SCHOOL, PUBLIC, BUILDING', 'APARTMENT', 'APARTMENT', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'STREET', 'APARTMENT', 'APARTMENT', 'CURRENCY EXCHANGE', 'RESIDENTIAL YARD (FRONT/BACK)', 'ALLEY', 'CTA TRAIN', 'RESIDENCE', 'RESTAURANT', 'OTHER', 'STREET', 'RESIDENCE', 'RESIDENCE PORCH/HALLWAY', 'APARTMENT', 'GAS STATION', 'SCHOOL, PUBLIC, GROUNDS', 'SIDEWALK', 'STREET', 'RESIDENCE-GARAGE', 'RESIDENCE', 'RESIDENCE-GARAGE', 'RESIDENCE', 'OTHER', 'APARTMENT', 'SIDEWALK', 'SCHOOL, PRIVATE, BUILDING', 'RESIDENCE', 'STREET', 'ALLEY', 'RESIDENCE', 'HOTEL/MOTEL', 'SIDEWALK', 'RESIDENCE PORCH/HALLWAY', 'SIDEWALK', 'ALLEY', 'SIDEWALK', 'ALLEY', 'ALLEY', 'RESIDENCE', 'ALLEY', 'CTA BUS', 'DEPARTMENT STORE', 'RESTAURANT', 'RESIDENCE', 'STREET', 'SIDEWALK', 'DEPARTMENT STORE', 'OTHER', 'APARTMENT', 'RESIDENTIAL YARD (FRONT/BACK)', 'HOTEL/MOTEL', 'BAR OR TAVERN', 'APARTMENT', 'STREET', 'STREET', 'APARTMENT', 'OTHER', 'SCHOOL, PRIVATE, BUILDING', 'ABANDONED BUILDING', 'GAS STATION', 'APARTMENT', 'BANK', 'STREET', 'RESIDENCE', 'SMALL RETAIL STORE', 'APARTMENT', 'STREET', 'RESIDENCE', 'STREET', 'STREET', 'RESIDENCE', 'APARTMENT', 'RESTAURANT', 'APARTMENT', 'STREET', 'STREET', 'RESIDENCE', 'ABANDONED BUILDING', 'RESIDENCE', 'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'PARKING LOT/GARAGE(NON.RESID.)', 'SIDEWALK', 'RESIDENCE', 'RESIDENCE', 'RESIDENCE', 'STREET', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'RESIDENCE', 'STREET', 'SIDEWALK', 'RESIDENTIAL YARD (FRONT/BACK)', 'SMALL RETAIL STORE', 'RESIDENCE', 'PARKING LOT/GARAGE(NON.RESID.)', 'BANK', 'RESIDENCE', 'ALLEY', 'RESTAURANT', 'APARTMENT', 'STREET', 'RESIDENCE PORCH/HALLWAY', 'SIDEWALK', 'DEPARTMENT STORE', 'GAS STATION', 'PARKING LOT/GARAGE(NON.RESID.)', 'PARK PROPERTY', 'RESIDENTIAL YARD (FRONT/BACK)', 'VEHICLE NON-COMMERCIAL', 'STREET', 'STREET', 'SIDEWALK', 'STREET', 'RESIDENCE', 'STREET', 'APARTMENT', 'ATM (AUTOMATIC TELLER MACHINE)', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'GAS STATION', 'CTA BUS', 'RESIDENCE', 'STREET', 'DEPARTMENT STORE', 'SIDEWALK', 'SIDEWALK', 'STREET', 'RESIDENCE', 'STREET', 'SIDEWALK', 'ALLEY', 'SIDEWALK', 'STREET', 'RESIDENCE', 'APARTMENT', 'ALLEY', 'SIDEWALK', 'STREET', 'STREET', 'OTHER', 'RESIDENCE', 'RESIDENCE', 'SCHOOL, PUBLIC, BUILDING', 'PARKING LOT/GARAGE(NON.RESID.)', 'RESIDENCE', 'ALLEY', 'STREET', 'APARTMENT', nan, 'SCHOOL, PUBLIC, BUILDING', 'STREET', 'APARTMENT', 'GROCERY FOOD STORE', 'RESIDENCE', 'STREET', 'GROCERY FOOD STORE', 'APARTMENT', 'STREET', 'STREET', 'APARTMENT', 'STREET', 'STREET', 'RESTAURANT', 'STREET', 'STREET', 'SCHOOL, PUBLIC, GROUNDS', 'SIDEWALK', 'APARTMENT', 'OTHER', 'OTHER', nan, 'SIDEWALK', 'STREET', 'STREET', 'STREET', 'SIDEWALK', 'SIDEWALK', 'CURRENCY EXCHANGE', 'SIDEWALK', 'APARTMENT', 'ALLEY', 'STREET', 'RESIDENCE', 'APARTMENT', 'APARTMENT', 'STREET', 'STREET', 'RESIDENCE', 'CTA STATION', 'STREET', 'STREET', 'RESIDENCE', 'GAS STATION', 'RESIDENCE', 'APARTMENT', 'STREET', 'RESIDENCE', 'STREET', 'STREET', 'STREET', 'DEPARTMENT STORE', 'RESIDENCE', 'ALLEY', 'DRUG STORE', 'STREET', 'STREET', 'SCHOOL, PUBLIC, BUILDING', 'RESIDENCE', 'STREET', 'SIDEWALK', 'DEPARTMENT STORE', 'RESIDENCE', 'STREET', 'APARTMENT', 'PARK PROPERTY', 'VEHICLE NON-COMMERCIAL', 'RES ...

# %% [markdown]
# Using the `locations_by_month` dictionary from the prior exercise, you'll now determine common crimes by month and location type. Because your dataset is so large, it's a good idea to use Counter to look at an aspect of it in an easier to manageable size and learn more about it.
#
# **Instructions**
# - Import `Counter` from `collections`.
# - Loop over the items from your dictionary, using tuple expansion to unpack `locations_by_month.items()` into `month` and `locations`.
#   - Make a Counter of the `locations` called `location_count`.
#   - Print the `month`.
#   - Print the five most common crime locations.

# %%
# Import Counter from collections
from collections import Counter

# Loop over the items from locations_by_month using tuple expansion of the month and locations
for month , locations in locations_by_month.items():
    # Make a Counter of the locations
    location_count = Counter(locations)
    # Print the month 
    print(month)
    # Print the most common location
    print(location_count.most_common(5))
# Out:
# 5
# [('STREET', 241), ('RESIDENCE', 175), ('APARTMENT', 128), ('SIDEWALK', 111), ('OTHER', 41)]
# 3
# [('STREET', 240), ('RESIDENCE', 190), ('APARTMENT', 139), ('SIDEWALK', 99), ('OTHER', 52)]
# 4
# [('STREET', 213), ('RESIDENCE', 171), ('APARTMENT', 152), ('SIDEWALK', 96), ('OTHER', 40)]
# 6
# [('STREET', 245), ('RESIDENCE', 164), ('APARTMENT', 159), ('SIDEWALK', 123), ('PARKING LOT/GARAGE(NON.RESID.)', 44)]
# 7
# [('STREET', 309), ('RESIDENCE', 177), ('APARTMENT', 166), ('SIDEWALK', 125), ('OTHER', 47)]
# 10
# [('STREET', 248), ('RESIDENCE', 206), ('APARTMENT', 122), ('SIDEWALK', 92), ('OTHER', 62)]
# 12
# [('STREET', 207), ('RESIDENCE', 158), ('APARTMENT', 136), ('OTHER', 47), ('SIDEWALK', 46)]
# 1
# [('STREET', 196), ('RESIDENCE', 160), ('APARTMENT', 153), ('SIDEWALK', 72), ('PARKING LOT/GARAGE(NON.RESID.)', 43)]
# 9
# [('STREET', 279), ('RESIDENCE', 183), ('APARTMENT', 144), ('SIDEWALK', 121), ('OTHER', 39)]
# 11
# [('STREET', 236), ('RESIDENCE', 182), ('APARTMENT', 154), ('SIDEWALK', 75), ('OTHER', 41)]
# 8
# [('STREET', 280), ('RESIDENCE', 199), ('APARTMENT', 144), ('SIDEWALK', 109), ('OTHER', 47)]
# 2
# [('STREET', 188), ('RESIDENCE', 159), ('APARTMENT', 144), ('SIDEWALK', 73), ('OTHER', 40)]

# %% [markdown]
# Your data file, `crime_sampler.csv` contains in positional order: the date, block where it occurred, primary type of the crime, description of the crime, description of the location, if an arrest was made, was it a domestic case, and city district.
#
# You'll now use a DictReader to load up a dictionary to hold your data with the district as the key and the rest of the data in a list. The `csv`, `defaultdict`, and `datetime` modules have already been imported for you.
#
# **Instructions**
# - Create a Python file object in read mode for `crime_sampler.csv` called `csvfile`.
# - Create a dictionary that defaults to a list called `crimes_by_district`.
# - Loop over a DictReader of the CSV file:
#   - Pop `'District'` from each row and store it as `district`.
#   - Append the rest of the data (`row`) to the `district` key of `crimes_by_district`.

# %%
# Create the CSV file: csvfile
csvfile = open('CSV/crime_sampler.csv','r')
#print(csvfile)
# Create a dictionary that defaults to a list: crimes_by_district
crimes_by_district = defaultdict(list)

# Loop over a DictReader of the CSV file
for row in csv.DictReader(csvfile):
    #print(row)
    #print(row['District'])
    # Pop the district from each row: district
    district = row.pop('District')
    # Append the rest of the data to the list for proper district in crimes_by_district
    crimes_by_district[district].append(row)

# %% [markdown]
# Using your `crimes_by_district` dictionary from the previous exercise, you'll now determine the number arrests in each City district for each year. `Counter` is already imported for you. You'll want to use the IPython Shell to explore the `crimes_by_district` dictionary to determine how to check if an arrest was made.
#
# **Instructions**
# - Loop over the `crimes_by_district` dictionary, unpacking it into the variables `district` and `crimes`.
#   - Create an empty Counter object called `year_count`.
#   - Loop over the `crimes`:
#     - If there was an arrest,
#     - Convert `crime['Date']` to a datetime object called `year`.
# - Add the crime to the Counter for the `year`, by using `year` as the key of `year_count`.
# - Print the Counter. This has been done for you!

# %%
# Loop over the crimes_by_district using expansion as district and crimes
for district,  crimes in crimes_by_district.items():
    # Print the district
    print(district)
    
    # Create an empty Counter object: year_count
    year_count = Counter()
    
    # Loop over the crimes:
    for crime in crimes:
        print(crime)
        # If there was an arrest
        if crime['Arrest'] == 'true':
            # Convert the Date to a datetime and get the year
            year = datetime.strptime(crime['Date'], '%m/%d/%Y %I:%M:%S %p').year
            # Increment the Counter for the year
            year_count[year] += 1
            
    # Print the counter
    print(year_count)
# Out:
# 14
# {'Date': '05/23/2016 05:35:00 PM', 'Block': '024XX W DIVISION ST', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '09/22/2016 03:00:00 PM', 'Block': '027XX N SPAULDING AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/24/2016 05:13:00 AM', 'Block': '033XX W BARRY AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/20/2016 05:00:00 PM', 'Block': '020XX W le moyne st', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/08/2016 02:30:00 AM', 'Block': '018XX W EVERGREEN AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/06/2016 01:50:00 PM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '07/28/2016 12:55:00 AM', 'Block': '031XX W LOGAN BLVD', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'BAR OR TAVERN', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/07/2016 06:20:00 PM', 'Block': '016XX N DAMEN AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/13/2016 02:25:00 AM', 'Block': '026XX N MILWAUKEE AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'CTA STATION', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/17/2017 06:00:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/05/2016 10:00:00 AM', 'Block': '022XX W ARMITAGE AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/03/2016 08:00:00 AM', 'Block': '021XX N STAVE ST', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/26/2016 10:43:00 PM', 'Block': '034XX W DICKENS AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '07/31/2016 08:49:00 PM', 'Block': '026XX W LE MOYNE ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO CITY OF CHICAGO PROPERTY', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/07/2016 10:57:00 PM', 'Block': '032XX W WABANSIA AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'TELEPHONE THREAT', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/08/2016 11:05:00 PM', 'Block': '018XX N KIMBALL AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/14/2016 04:10:00 PM', 'Block': '013XX N ASHLAND AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'COMMERCIAL / BUSINESS OFFICE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/09/2016 09:00:00 PM', 'Block': '020XX N KEDZIE AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/16/2016 12:00:00 AM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '01/17/2017 05:58:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/19/2016 09:10:00 AM', 'Block': '015XX N WASHTENAW AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'VEHICLE NON-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/20/2016 04:00:00 PM', 'Block': '033XX W BELDEN AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'THEFT/RECOVERY: AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/24/2016 09:20:00 AM', 'Block': '017XX W ELLEN ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'DRIVEWAY - RESIDENTIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/17/2016 06:00:00 AM', 'Block': '024XX N BERNARD ST', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/18/2016 09:15:00 AM', 'Block': '014XX N MILWAUKEE AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/03/2016 03:30:00 PM', 'Block': '026XX N MILWAUKEE AVE', 'Primary Type': 'SEX OFFENSE', 'Description': 'PUBLIC INDECENCY', 'Location Description': 'CTA TRAIN', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/26/2016 02:40:00 AM', 'Block': '019XX N RICHMOND ST', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO RESIDENCE', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '04/19/2016 08:15:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2016 10:30:00 PM', 'Block': '022XX W FULLERTON AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/06/2017 06:16:00 PM', 'Block': '033XX W SCHUBERT AVE', 'Primary Type': 'ROBBERY', 'Description': 'ATTEMPT: ARMED-KNIFE/CUT INSTR', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/16/2016 05:47:00 AM', 'Block': '013XX N PAULINA ST', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/05/2016 03:00:00 PM', 'Block': '015XX N MAGNOLIA AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/18/2017 05:00:00 AM', 'Block': '015XX N CAMPBELL AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '11/29/2016 02:42:00 PM', 'Block': '017XX N WESTERN AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/26/2016 06:10:00 PM', 'Block': '016XX N ASHLAND AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'CTA BUS', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/24/2017 01:00:00 PM', 'Block': '015XX N FAIRFIELD AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/07/2017 05:50:00 PM', 'Block': '022XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/30/2016 06:00:00 PM', 'Block': '035XX W DICKENS AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/02/2016 01:30:00 PM', 'Block': '024XX N CALIFORNIA AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'BOGUS CHECK', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/15/2017 09:00:00 AM', 'Block': '024XX W DIVISION ST', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/27/2016 05:17:00 PM', 'Block': '016XX W NORTH AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'GAS STATION', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/14/2016 07:00:00 AM', 'Block': '034XX W DRUMMOND PL', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2016 12:01:00 AM', 'Block': '020XX N POINT ST', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'CREDIT CARD FRAUD', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/16/2016 09:30:00 PM', 'Block': '016XX W WABANSIA AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/18/2016 10:48:00 PM', 'Block': '014XX N CALIFORNIA AVE', 'Primary Type': 'ASSAULT', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/17/2016 10:00:00 PM', 'Block': '033XX W WABANSIA AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/28/2016 02:00:00 PM', 'Block': '028XX N WESTERN AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/06/2016 11:00:00 PM', 'Block': '012XX N PAULINA ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/17/2016 04:13:00 PM', 'Block': '026XX W GEORGE ST', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY ELECTRONIC MEANS', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/04/2016 10:00:00 PM', 'Block': '033XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/29/2016 07:45:00 PM', 'Block': '026XX W HIRSCH ST', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '01/10/2017 09:00:00 PM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'POCKET-PICKING', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/02/2016 10:08:00 PM', 'Block': '019XX N WESTERN AVE', 'Primary Type': 'ASSAULT', 'Description': 'PRO EMP HANDS NO/MIN INJURY', 'Location Description': 'CTA STATION', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/26/2016 04:37:00 AM', 'Block': '014XX N WOOD ST', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY ELECTRONIC MEANS', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '09/02/2016 09:40:00 PM', 'Block': '015XX N WASHTENAW AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'PAROLE VIOLATION', 'Location Description': 'STREET', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '03/04/2017 12:01:00 AM', 'Block': '013XX W POTOMAC AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/13/2017 07:15:00 PM', 'Block': '034XX W DIVERSEY AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/30/2016 12:30:00 AM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '10/15/2016 08:30:00 PM', 'Block': '022XX N DRAKE AVE', 'Primary Type': 'ROBBERY', 'Description': 'STRONGARM - NO WEAPON', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/01/2017 07:04:00 PM', 'Block': '032XX W LE MOYNE ST', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/28/2017 04:32:00 AM', 'Block': '027XX N ST LOUIS AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY ELECTRONIC MEANS', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/09/2016 06:00:00 PM', 'Block': '028XX N WESTERN AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/19/2016 11:00:00 AM', 'Block': '025XX W BLOOMINGDALE AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '10/06/2016 06:25:00 AM', 'Block': '012XX N MILWAUKEE AVE', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO STATE SUP LAND', 'Location Description': 'CTA STATION', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '02/26/2016 12:40:00 AM', 'Block': '028XX W DIVERSEY AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/15/2016 12:30:00 PM', 'Block': '016XX N CAMPBELL AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/13/2016 01:45:00 PM', 'Block': '014XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/10/2016 11:00:00 AM', 'Block': '013XX N WESTERN AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/07/2016 07:00:00 AM', 'Block': '025XX N CAMPBELL AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '09/16/2016 11:55:00 AM', 'Block': '020XX N SPAULDING AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/12/2017 12:20:00 PM', 'Block': '013XX N ELSTON AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/15/2016 11:00:00 PM', 'Block': '035XX W BELDEN AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '12/05/2016 07:00:00 PM', 'Block': '034XX W SHAKESPEARE AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/15/2016 11:10:00 AM', 'Block': '033XX W EVERGREEN AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'CHA PARKING LOT/GROUNDS', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/11/2016 07:30:00 PM', 'Block': '022XX N ST LOUIS AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/21/2017 01:05:00 PM', 'Block': '021XX N MOZART ST', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/15/2016 10:00:00 PM', 'Block': '026XX W LOGAN BLVD', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO VEHICLE', 'Location Description': 'VEHICLE NON-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/13/2016 01:00:00 PM', 'Block': '014XX N OAKLEY BLVD', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/30/2016 10:00:00 PM', 'Block': '016XX N ARTESIAN AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/25/2016 05:30:00 PM', 'Block': '016XX N ADA ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/16/2016 04:30:00 PM', 'Block': '032XX W PALMER ST', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/23/2016 10:00:00 AM', 'Block': '035XX W BARRY AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/18/2017 05:30:00 PM', 'Block': '035XX W DIVERSEY AVE', 'Primary Type': 'SEX OFFENSE', 'Description': 'AGG CRIMINAL SEXUAL ABUSE', 'Location Description': 'OTHER', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '07/21/2016 10:25:00 AM', 'Block': '027XX W DIVISION ST', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/03/2016 09:00:00 PM', 'Block': '018XX N MARSHFIELD AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/08/2016 03:03:00 PM', 'Block': '025XX W CORTLAND ST', 'Primary Type': 'ASSAULT', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/03/2016 11:40:00 AM', 'Block': '032XX W EVERGREEN AVE', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO RESIDENCE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '01/20/2016 01:00:00 PM', 'Block': '034XX W DIVISION ST', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/21/2016 01:10:00 PM', 'Block': '033XX W NORTH AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'BANK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/19/2016 05:00:00 PM', 'Block': '017XX N WESTERN AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/01/2017 06:13:00 AM', 'Block': '014XX N CAMPBELL AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'TELEPHONE THREAT', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/06/2017 06:45:00 AM', 'Block': '020XX W FULLERTON AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/14/2016 10:00:00 PM', 'Block': '022XX W NORTH AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/10/2016 04:20:00 AM', 'Block': '021XX W SCHILLER ST', 'Primary Type': 'ROBBERY', 'Description': 'ARMED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '02/09/2016 06:00:00 PM', 'Block': '028XX N MILWAUKEE AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'MEDICAL/DENTAL OFFICE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/26/2016 07:30:00 PM', 'Block': '021XX N CAMPBELL AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/11/2017 12:44:00 AM', 'Block': '023XX N MILWAUKEE AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/10/2016 08:00:00 AM', 'Block': '020XX N WHIPPLE ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/11/2016 08:00:00 AM', 'Block': '017XX N DAMEN AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': '', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/04/2017 05:00:00 PM', 'Block': '020XX N STAVE ST', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/30/2017 07:25:00 PM', 'Block': '017XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'ATHLETIC CLUB', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/16/2016 08:55:00 AM', 'Block': '023XX N LEAVITT ST', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/28/2016 05:30:00 PM', 'Block': '025XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/17/2016 10:00:00 AM', 'Block': '016XX N FAIRFIELD AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/06/2016 08:31:00 PM', 'Block': '018XX N WASHTENAW AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/22/2016 10:39:00 PM', 'Block': '035XX W WABANSIA AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '09/22/2016 01:00:00 AM', 'Block': '018XX W ARMITAGE AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/19/2016 09:43:00 PM', 'Block': '024XX W MOFFAT ST', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'RESIDENTIAL YARD (FRONT/BACK)', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '06/02/2016 10:00:00 PM', 'Block': '016XX W CORTLAND ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/11/2016 03:00:00 PM', 'Block': '018XX N MARSHFIELD AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'PARK PROPERTY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/24/2016 12:00:00 PM', 'Block': '013XX N ARTESIAN AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/19/2016 02:51:00 PM', 'Block': '026XX N FAIRFIELD AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/16/2017 07:00:00 PM', 'Block': '026XX N CALIFORNIA AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/01/2016 12:00:00 PM', 'Block': '032XX W FULLERTON AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/15/2016 03:30:00 AM', 'Block': '015XX N MAPLEWOOD AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'COMMERCIAL / BUSINESS OFFICE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/14/2016 12:30:00 PM', 'Block': '033XX W FULLERTON AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '01/04/2016 03:00:00 PM', 'Block': '016XX N KIMBALL AVE', 'Primary Type': 'PUBLIC PEACE VIOLATION', 'Description': 'ARSON THREAT', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '07/10/2016 04:45:00 PM', 'Block': '012XX N LUIS MUNOZ MARIN DR E', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'PARK PROPERTY', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '12/03/2016 04:00:00 PM', 'Block': '034XX W BEACH AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/12/2016 05:15:00 PM', 'Block': '033XX W CRYSTAL ST', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/09/2017 06:30:00 AM', 'Block': '027XX W POTOMAC AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/30/2016 09:00:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/27/2016 03:00:00 PM', 'Block': '018XX N CALIFORNIA AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/29/2016 08:00:00 AM', 'Block': '020XX N WHIPPLE ST', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'CREDIT CARD FRAUD', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/26/2016 08:00:00 AM', 'Block': '020XX N WHIPPLE ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/16/2016 06:00:00 AM', 'Block': '021XX W LE MOYNE ST', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/12/2016 10:00:00 PM', 'Block': '022XX N SPAULDING AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'VEHICLE NON-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/24/2016 08:30:00 PM', 'Block': '013XX N WOLCOTT AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/27/2016 02:05:00 AM', 'Block': '027XX N WESTERN AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'RESTAURANT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/28/2016 06:09:00 PM', 'Block': '023XX W MC LEAN AVE', 'Primary Type': 'ROBBERY', 'Description': 'STRONGARM - NO WEAPON', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/11/2016 02:00:00 PM', 'Block': '017XX N WASHTENAW AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/13/2016 08:50:00 AM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'INTERFERENCE WITH PUBLIC OFFICER', 'Description': 'INTERFERENCE JUDICIAL PROCESS', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/16/2016 08:00:00 PM', 'Block': '024XX N WESTERN AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/14/2017 01:56:00 PM', 'Block': '013XX N MILWAUKEE AVE', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO VEHICLE', 'Location Description': 'ALLEY', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '09/17/2016 01:39:00 AM', 'Block': '012XX N MILWAUKEE AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/11/2016 09:50:00 PM', 'Block': '020XX W DIVISION ST', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/30/2016 12:10:00 AM', 'Block': '033XX W BARRY AVE', 'Primary Type': 'ROBBERY', 'Description': 'ARMED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/24/2016 01:28:00 AM', 'Block': '016XX N TROY ST', 'Primary Type': 'BURGLARY', 'Description': 'ATTEMPT FORCIBLE ENTRY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/14/2017 12:01:00 AM', 'Block': '014XX N CALIFORNIA AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'NURSING HOME/RETIREMENT HOME', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/19/2016 09:42:00 PM', 'Block': '034XX W HIRSCH ST', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/30/2016 02:00:00 AM', 'Block': '027XX N SPAULDING AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/15/2016 08:35:00 PM', 'Block': '033XX W ARMITAGE AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/25/2016 07:40:00 PM', 'Block': '032XX W ALTGELD ST', 'Primary Type': 'ROBBERY', 'Description': 'ARMED: HANDGUN', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/18/2017 11:35:00 PM', 'Block': '028XX W SHAKESPEARE AVE', 'Primary Type': 'ROBBERY', 'Description': 'VEHICULAR HIJACKING', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/09/2016 08:00:00 PM', 'Block': '017XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'RESTAURANT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/05/2016 12:47:00 PM', 'Block': '023XX N ST LOUIS AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: OTHER DANG WEAPON', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/13/2016 06:50:00 PM', 'Block': '020XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'CONVENIENCE STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/22/2016 04:10:00 AM', 'Block': '023XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/26/2016 04:15:00 PM', 'Block': '021XX W CONCORD PL', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/28/2016 04:30:00 PM', 'Block': '021XX N STAVE ST', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/29/2016 08:00:00 PM', 'Block': '018XX N MARSHFIELD AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '05/28/2016 08:05:00 PM', 'Block': '017XX N WOOD ST', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/17/2016 06:30:00 PM', 'Block': '013XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/14/2016 07:00:00 PM', 'Block': '014XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2017 01:22:00 AM', 'Block': '035XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GAS STATION', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/22/2016 02:30:00 PM', 'Block': '022XX N CALIFORNIA AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'CTA TRAIN', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/26/2016 10:30:00 PM', 'Block': '025XX N KEDZIE BLVD', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/04/2016 09:00:00 AM', 'Block': '016XX N MILWAUKEE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': 'HOSPITAL BUILDING/GROUNDS', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/24/2016 03:04:00 AM', 'Block': '030XX W ARMITAGE AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'OTHER CRIME AGAINST PERSON', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/13/2016 06:00:00 PM', 'Block': '019XX N HONORE ST', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/27/2016 03:20:00 PM', 'Block': '016XX N DAMEN AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/22/2016 01:53:00 AM', 'Block': '014XX N WICKER PARK AVE', 'Primary Type': 'ROBBERY', 'Description': 'AGGRAVATED VEHICULAR HIJACKING', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/19/2016 08:00:00 AM', 'Block': '031XX N ROCKWELL ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'TRUCK, BUS, MOTOR HOME', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/10/2016 10:35:00 AM', 'Block': '016XX W LE MOYNE ST', 'Primary Type': 'OTHER OFFENSE', 'Description': 'SEX OFFENDER: FAIL REG NEW ADD', 'Location Description': 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/22/2016 10:30:00 AM', 'Block': '027XX N CAMPBELL AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/18/2016 05:00:00 PM', 'Block': '015XX W LE MOYNE ST', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/15/2016 05:18:00 AM', 'Block': '022XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2017 05:00:00 PM', 'Block': '033XX W LE MOYNE ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'CRIMINAL DEFACEMENT', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/26/2016 09:52:00 AM', 'Block': '030XX W MEDILL AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY TELEPHONE', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/12/2017 09:23:00 PM', 'Block': '028XX W NORTH AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/10/2017 04:53:00 PM', 'Block': '034XX W POTOMAC AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/12/2016 07:22:00 PM', 'Block': '016XX N ADA ST', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/01/2016 09:25:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/17/2016 01:30:00 PM', 'Block': '020XX W LE MOYNE ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/19/2017 11:00:00 PM', 'Block': '021XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/02/2016 07:15:00 PM', 'Block': '019XX N MILWAUKEE AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/05/2017 10:00:00 PM', 'Block': '019XX N LEAVITT ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/20/2016 12:30:00 PM', 'Block': '028XX N KIMBALL AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'CTA BUS', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '04/07/2016 09:15:00 PM', 'Block': '016XX N CLAREMONT AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/20/2017 05:30:00 PM', 'Block': '033XX W CRYSTAL ST', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY ELECTRONIC MEANS', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/19/2017 09:00:00 AM', 'Block': '015XX N OAKLEY BLVD', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/29/2016 05:00:00 PM', 'Block': '026XX W NORTH AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/01/2016 11:40:00 AM', 'Block': '019XX W FULLERTON AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'COUNTERFEITING DOCUMENT', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/17/2017 04:30:00 PM', 'Block': '021XX N MOZART ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/16/2016 12:45:00 AM', 'Block': '033XX W CRYSTAL ST', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '04/28/2016 09:00:00 AM', 'Block': '030XX W NORTH AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/17/2016 04:39:00 PM', 'Block': '025XX N KEDZIE BLVD', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED PO: OTHER DANG WEAP', 'Location Description': 'OTHER', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '10/22/2016 03:30:00 AM', 'Block': '032XX W DIVERSEY AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: OTHER DANG WEAPON', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/11/2017 06:20:00 PM', 'Block': '014XX N ELK GROVE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'CREDIT CARD FRAUD', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/11/2016 08:34:00 AM', 'Block': '018XX N CALIFORNIA AVE', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO RESIDENCE', 'Location Description': 'OTHER', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '07/24/2016 08:45:00 PM', 'Block': '014XX N DAMEN AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/30/2016 02:00:00 AM', 'Block': '024XX N BERNARD ST', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/12/2016 09:00:00 AM', 'Block': '015XX N ELK GROVE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/19/2016 10:00:00 PM', 'Block': '023XX W MONTANA ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/30/2016 04:30:00 PM', 'Block': '020XX W SCHILLER ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/06/2016 12:00:00 AM', 'Block': '028XX W LE MOYNE DR', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/12/2016 12:00:00 PM', 'Block': '025XX N KEDZIE BLVD', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'VEHICLE NON-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/16/2017 04:38:00 AM', 'Block': '032XX W BELDEN AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '01/03/2017 04:00:00 AM', 'Block': '030XX N ELBRIDGE AVE', 'Primary Type': 'SEX OFFENSE', 'Description': 'OTHER', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '08/04/2016 08:00:00 PM', 'Block': '017XX N ARTESIAN AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/08/2016 04:29:00 PM', 'Block': '024XX N ALBANY AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY TELEPHONE', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '01/19/2016 03:15:00 PM', 'Block': '033XX W NORTH AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'RESTAURANT', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '08/18/2016 01:30:00 PM', 'Block': '013XX N GREENVIEW AVE', 'Primary Type': 'ROBBERY', 'Description': 'ARMED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/17/2016 11:30:00 AM', 'Block': '013XX N LEAVITT ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/01/2016 08:00:00 PM', 'Block': '026XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'DEPARTMENT STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/31/2016 06:00:00 PM', 'Block': '016XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/08/2016 04:35:00 AM', 'Block': '020XX N DAMEN AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'CONVENIENCE STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/12/2016 03:03:00 AM', 'Block': '021XX W SCHILLER ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2016 10:01:00 AM', 'Block': '014XX N WESTERN AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '05/14/2016 07:30:00 PM', 'Block': '016XX N BELL AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/25/2016 01:00:00 PM', 'Block': '023XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'VEHICLE-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/04/2016 03:30:00 PM', 'Block': '020XX W CONCORD PL', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/02/2016 08:00:00 PM', 'Block': '015XX N HOYNE AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/18/2016 10:02:00 AM', 'Block': '015XX N OAKLEY BLVD', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/11/2016 09:00:00 AM', 'Block': '031XX W ARMITAGE AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'MEDICAL/DENTAL OFFICE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/27/2016 09:31:00 PM', 'Block': '026XX W FULLERTON AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/03/2017 04:42:00 PM', 'Block': '016XX N TROY ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'LIBRARY VANDALISM', 'Location Description': 'LIBRARY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/11/2016 07:00:00 PM', 'Block': '015XX N TALMAN AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/01/2016 09:00:00 AM', 'Block': '032XX W BEACH AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT $300 AND UNDER', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/25/2016 06:00:00 PM', 'Block': '018XX N HERMITAGE AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/01/2017 07:25:00 AM', 'Block': '021XX N SAWYER AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/01/2016 04:30:00 AM', 'Block': '020XX N WESTERN AVE', 'Primary Type': 'THEFT', 'Description': 'PURSE-SNATCHING', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/15/2016 01:30:00 AM', 'Block': '019XX N RICHMOND ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/04/2016 12:00:00 AM', 'Block': '013XX N BELL AVE', 'Primary Type': 'OFFENSE INVOLVING CHILDREN', 'Description': 'CRIM SEX ABUSE BY FAM MEMBER', 'Location Description': 'ALLEY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/17/2016 12:30:00 PM', 'Block': '015XX N KEDZIE AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '09/05/2016 09:00:00 AM', 'Block': '023XX W FULLERTON AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GAS STATION', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/05/2016 01:25:00 PM', 'Block': '023XX N LEAVITT ST', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/25/2016 04:40:00 PM', 'Block': '015XX N MILWAUKEE AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/04/2016 05:15:00 PM', 'Block': '021XX N CENTRAL PARK AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# ...
# {'Date': '04/02/2016 10:30:00 PM', 'Block': '045XX N CICERO AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/01/2017 07:00:00 PM', 'Block': '043XX N RIDGEWAY AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'RESIDENCE-GARAGE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/03/2016 12:50:00 PM', 'Block': '034XX W BELMONT AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/25/2017 04:00:00 PM', 'Block': '051XX N KOSTNER AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SCHOOL, PUBLIC, GROUNDS', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/10/2016 04:45:00 PM', 'Block': '046XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/07/2016 05:30:00 AM', 'Block': '050XX N SPAULDING AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'SCHOOL, PRIVATE, BUILDING', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/01/2016 07:00:00 AM', 'Block': '050XX N KENNETH AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SCHOOL, PUBLIC, BUILDING', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/05/2016 08:30:00 AM', 'Block': '063XX N LOWELL AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '07/18/2016 05:30:00 PM', 'Block': '032XX N KIMBALL AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'PAWN SHOP', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/07/2016 04:15:00 AM', 'Block': '040XX N KEDZIE AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/09/2016 04:05:00 PM', 'Block': '039XX W ROSCOE ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/05/2016 07:30:00 PM', 'Block': '040XX N KILDARE AVE', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO VEHICLE', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/13/2016 06:00:00 PM', 'Block': '036XX N PULASKI RD', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'VEHICLE NON-COMMERCIAL', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/12/2016 07:30:00 PM', 'Block': '039XX N MILWAUKEE AVE', 'Primary Type': 'NARCOTICS', 'Description': 'POSS: CANNABIS 30GMS OR LESS', 'Location Description': 'STREET', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '05/09/2016 08:33:00 AM', 'Block': '062XX N LINCOLN AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/07/2017 02:20:00 PM', 'Block': '040XX W FOSTER AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '09/06/2016 04:26:00 AM', 'Block': '047XX N ST LOUIS AVE', 'Primary Type': 'BURGLARY', 'Description': 'UNLAWFUL ENTRY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/10/2016 10:30:00 PM', 'Block': '058XX N BERNARD ST', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/12/2017 06:30:00 PM', 'Block': '031XX W CARMEN AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/21/2016 02:00:00 PM', 'Block': '043XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/18/2017 08:00:00 AM', 'Block': '030XX W AINSLIE ST', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'PARKING LOT/GARAGE(NON.RESID.)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/17/2016 12:17:00 AM', 'Block': '045XX N KEDZIE AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'BARBERSHOP', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/20/2016 09:05:00 AM', 'Block': '037XX W MONTROSE AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '04/21/2016 10:00:00 AM', 'Block': '048XX N SAWYER AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FINANCIAL IDENTITY THEFT OVER $ 300', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/20/2016 03:00:00 PM', 'Block': '036XX N RICHMOND ST', 'Primary Type': 'OTHER OFFENSE', 'Description': 'TELEPHONE THREAT', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '06/10/2016 09:00:00 AM', 'Block': '040XX N KILDARE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'ILLEGAL USE CASH CARD', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/04/2016 07:00:00 PM', 'Block': '034XX N CENTRAL PARK AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/04/2016 05:10:00 PM', 'Block': '032XX W BELMONT AVE', 'Primary Type': 'ASSAULT', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/08/2016 10:00:00 PM', 'Block': '046XX N PULASKI RD', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'POLICE FACILITY/VEH PARKING LOT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/07/2016 11:50:00 AM', 'Block': '039XX N PULASKI RD', 'Primary Type': 'CRIMINAL TRESPASS', 'Description': 'TO RESIDENCE', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/07/2016 01:15:00 PM', 'Block': '039XX W DAKIN ST', 'Primary Type': 'ASSAULT', 'Description': 'AGGRAVATED: HANDGUN', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/10/2016 01:00:00 AM', 'Block': '037XX W LAWRENCE AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/16/2017 05:00:00 PM', 'Block': '041XX N KEYSTONE AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '08/02/2016 09:00:00 AM', 'Block': '063XX N MC CORMICK RD', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'FRAUD OR CONFIDENCE GAME', 'Location Description': 'BANK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/13/2016 05:00:00 PM', 'Block': '039XX N RIDGEWAY AVE', 'Primary Type': 'ROBBERY', 'Description': 'STRONGARM - NO WEAPON', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/06/2016 12:40:00 PM', 'Block': '035XX W GRACE ST', 'Primary Type': 'NARCOTICS', 'Description': 'FOUND SUSPECT NARCOTICS', 'Location Description': 'SCHOOL, PUBLIC, GROUNDS', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '02/20/2017 08:36:00 PM', 'Block': '037XX W LAWRENCE AVE', 'Primary Type': 'NARCOTICS', 'Description': 'POSS: METHAMPHETAMINES', 'Location Description': 'STREET', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '10/28/2016 04:26:00 PM', 'Block': '043XX N PULASKI RD', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'ILLEGAL USE CASH CARD', 'Location Description': 'ATM (AUTOMATIC TELLER MACHINE)', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/03/2016 03:24:00 PM', 'Block': '047XX N SACRAMENTO AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/04/2016 08:29:00 AM', 'Block': '042XX W IRVING PARK RD', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/23/2017 09:15:00 PM', 'Block': '049XX N KILDARE AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '10/22/2016 02:30:00 PM', 'Block': '046XX W IRVING PARK RD', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'SMALL RETAIL STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '04/28/2016 04:40:00 PM', 'Block': '034XX W IRVING PARK RD', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/04/2016 05:01:00 PM', 'Block': '048XX N KIMBALL AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'CTA BUS', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/12/2016 03:15:00 PM', 'Block': '046XX N DRAKE AVE', 'Primary Type': 'BATTERY', 'Description': 'AGGRAVATED: OTHER DANG WEAPON', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/06/2017 01:43:00 PM', 'Block': '043XX N ELSTON AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '03/20/2016 10:15:00 AM', 'Block': '046XX N KEYSTONE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'ILLEGAL USE CASH CARD', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/14/2016 03:18:00 PM', 'Block': '039XX W CORNELIA AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'ATTEMPT - FINANCIAL IDENTITY THEFT', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '09/25/2016 02:00:00 AM', 'Block': '035XX W CULLOM AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/08/2017 06:15:00 PM', 'Block': '049XX N ST LOUIS AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '09/17/2016 06:13:00 PM', 'Block': '032XX W ARDMORE AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY TELEPHONE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/26/2016 06:00:00 AM', 'Block': '042XX N KEDVALE AVE', 'Primary Type': 'BURGLARY', 'Description': 'FORCIBLE ENTRY', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/24/2016 08:29:00 PM', 'Block': '048XX N KILPATRICK AVE', 'Primary Type': 'ASSAULT', 'Description': 'SIMPLE', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '12/22/2016 10:52:00 AM', 'Block': '033XX W IRVING PARK RD', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/19/2016 01:34:00 PM', 'Block': '038XX W EDDY ST', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO PROPERTY', 'Location Description': 'RESIDENCE PORCH/HALLWAY', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/11/2016 10:00:00 PM', 'Block': '030XX W BELMONT AVE', 'Primary Type': 'THEFT', 'Description': '$500 AND UNDER', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/19/2016 07:45:00 AM', 'Block': '034XX W BALMORAL AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'true'}
# {'Date': '04/18/2016 03:00:00 PM', 'Block': '041XX W LAWRENCE AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/04/2016 07:30:00 AM', 'Block': '049XX N MONTICELLO AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'HARASSMENT BY ELECTRONIC MEANS', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/07/2017 11:30:00 AM', 'Block': '038XX N KEDZIE AVE', 'Primary Type': 'DECEPTIVE PRACTICE', 'Description': 'ATTEMPT - FINANCIAL IDENTITY THEFT', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/09/2016 06:25:00 PM', 'Block': '032XX W BELMONT AVE', 'Primary Type': 'BATTERY', 'Description': 'SIMPLE', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/27/2017 04:15:00 PM', 'Block': '056XX N CENTRAL PARK AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/27/2016 04:20:00 PM', 'Block': '047XX N KEDZIE AVE', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'true', 'Domestic': 'false'}
# {'Date': '04/08/2016 10:30:00 AM', 'Block': '046XX W PETERSON AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'TELEPHONE THREAT', 'Location Description': 'OTHER', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '07/01/2016 01:00:00 AM', 'Block': '047XX N CENTRAL PARK AVE', 'Primary Type': 'ROBBERY', 'Description': 'STRONGARM - NO WEAPON', 'Location Description': 'SIDEWALK', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '12/20/2016 09:00:00 PM', 'Block': '058XX N CHRISTIANA AVE', 'Primary Type': 'THEFT', 'Description': 'OVER $500', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '06/25/2016 02:30:00 PM', 'Block': '048XX N KIMBALL AVE', 'Primary Type': 'CRIMINAL DAMAGE', 'Description': 'TO VEHICLE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '05/04/2016 04:21:00 PM', 'Block': '041XX W CORNELIA AVE', 'Primary Type': 'OTHER OFFENSE', 'Description': 'TELEPHONE THREAT', 'Location Description': 'RESIDENCE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '02/22/2017 02:00:00 PM', 'Block': '047XX N KIMBALL AVE', 'Primary Type': 'THEFT', 'Description': 'FROM BUILDING', 'Location Description': 'APARTMENT', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '04/23/2016 11:05:00 AM', 'Block': '049XX N SPAULDING AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '05/06/2016 06:00:00 PM', 'Block': '034XX N MILWAUKEE AVE', 'Primary Type': 'BATTERY', 'Description': 'DOMESTIC BATTERY SIMPLE', 'Location Description': 'APARTMENT', 'Arrest': 'true', 'Domestic': 'true'}
# {'Date': '01/14/2017 09:00:00 AM', 'Block': '050XX N ELSTON AVE', 'Primary Type': 'THEFT', 'Description': 'POCKET-PICKING', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '11/11/2016 02:00:00 PM', 'Block': '033XX N MONTICELLO AVE', 'Primary Type': 'MOTOR VEHICLE THEFT', 'Description': 'AUTOMOBILE', 'Location Description': 'STREET', 'Arrest': 'false', 'Domestic': 'false'}
# {'Date': '01/29/2017 01:20:00 PM', 'Block': '046XX W IRVING PARK RD', 'Primary Type': 'THEFT', 'Description': 'RETAIL THEFT', 'Location Description': 'GROCERY FOOD STORE', 'Arrest': 'false', 'Domestic': 'false'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# You're in the home stretch!
#
# Here, your data has been reshaped into a dictionary called `crimes_by_block` in which crimes are listed by city block. Your task in this exercise is to get a unique list of crimes that have occurred on a couple of the blocks that have been selected for you to learn more about. You might remember that you used `set()` to solve problems like this in earlier.
#
# Go for it!
#
# **Instructions**
# - Create a unique list of crimes for the `'001XX N STATE ST'` block called `n_state_st_crimes` and print it.
# - Create a unique list of crimes for the `'0000X W TERMINAL ST'` block called `w_terminal_st_crimes` and print it.
# - Find the crimes committed on `001XX N STATE ST` but not `0000X W TERMINAL ST`. Store the result as `crime_differences` and print it.

# %%
# Create the CSV file: csvfile
csvfile = open('CSV/crime_sampler.csv', 'r')

# Create a dictionary that defaults to a list: crimes_by_block
crimes_by_block = defaultdict(list)
#print(crimes_by_block)
# Loop over a csv reader on the file object
for row in csv.reader(csvfile):
    # Set the dictionary key to the 'Block' and add the 'Primary Type' to the values list
    crimes_by_block[row[1]].append(row[2])

# Remove header from crimes_by_block
del crimes_by_block['Block']

#print(crimes_by_block)

# %%
# Create a unique list of crimes for the first block: n_state_st_crimes
n_state_st_crimes = set(crimes_by_block['001XX N STATE ST'])

# Print the list
print(n_state_st_crimes)

# Create a unique list of crimes for the second block: w_terminal_st_crimes
w_terminal_st_crimes = set(crimes_by_block['0000X W TERMINAL ST'])

# Print the list
print(w_terminal_st_crimes)

# Find the differences between the two blocks: crime_differences
crime_differences = n_state_st_crimes.difference(w_terminal_st_crimes)

# Print the differences
print(sorted(crime_differences))
# Out:
# {'CRIMINAL TRESPASS', 'CRIMINAL DAMAGE', 'OTHER OFFENSE', 'ASSAULT', 'DECEPTIVE PRACTICE', 'ROBBERY', 'BATTERY', 'THEFT'}
# {'OTHER OFFENSE', 'CRIMINAL DAMAGE', 'CRIMINAL TRESPASS', 'ASSAULT', 'DECEPTIVE PRACTICE', 'PUBLIC PEACE VIOLATION', 'NARCOTICS', 'THEFT'}
# ['BATTERY', 'ROBBERY']
